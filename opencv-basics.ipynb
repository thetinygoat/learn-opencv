# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

# %%
img  = cv2.imread('./wallhaven-13ypx1_1920x1080.png')

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('./wallhaven-13ypx1_1920x1080.png', cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1080, 1920)

# %%
plt.imshow(img_gray, cmap="gray")

# %%
fix_img.shape
# Out:
# (1080, 1920, 3)

# %%
resized_img = cv2.resize(fix_img, (1280,720))

# %%
plt.imshow(resized_img)
